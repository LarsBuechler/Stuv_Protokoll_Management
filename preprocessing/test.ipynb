# %%
from pdf_handler import Pdf_Handler
import pandas as pd

# %%
pdf_reader = Pdf_Handler()

# %%
pdf_reader.get_pdf_list()

# %%
pdf_reader.pdf_df.to_csv("../document-classification/data/intermidiate/pdf_as_text.csv", index=False)

# %%
pd.read_csv("../document-classification/data/intermidiate/pdf_as_text.csv")
# Out:
#                                              filename  number_of_pages  \
# 0                             protokoll.pdf2021_07_15                9
# 1                             protokoll.pdf2021_08_17                4
# 2                             protokoll.pdf2021_09_13                6
# 3                             protokoll.pdf2021_10_05               12
# 4                      ressortzuschnitt.pdf2021_10_05                2
# 5                               solange.pdf2021_10_05                1
# 6                             protokoll.pdf2021_11_11               12
# 7                         klare_ansagen.pdf2021_12_20                2
# 8                             protokoll.pdf2022_01_24                7
# 9                                barmer.pdf2022_03_28                1
# 10                           beflaggung.pdf2022_03_28                1
# 11        digitaler_studierendenausweis.pdf2022_03_28                2
# ...
